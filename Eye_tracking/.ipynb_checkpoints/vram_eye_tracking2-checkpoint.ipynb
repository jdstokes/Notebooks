# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
sns.set(style="darkgrid")
import sys
sys.path.append('../src/Vrama')
from Vrama import Eye
import time
from scipy import stats
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
resultsList = []
subjList = ['19202','19205','19201']
for i in subjList:
    resultsList.append(GetSubjectData(i))
# Out:
# C:\Users\Greco\Anaconda3\envs\vram\lib\site-packages\IPython\core\interactiveshell.py:3296: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def GetSubjectData(subjectID):
    dfAll = Eye.LoadEyeData(subjectID)
    dfList = Eye.GetDfList(dfAll)
    df_scores_all = pd.DataFrame()
    df_scores_on = pd.DataFrame()
    df_scores_off = pd.DataFrame()

    for i in dfList:
        df = Eye.PreProcessDf(i)
        dfOn = Eye.GetDistractorOn(df)
        dfOff = Eye.GetDistractorOff(df)
        df_scores_all = df_scores_all.append(Eye.GetScores(df,df))
        df_scores_on = df_scores_on.append(Eye.GetScores(dfOn,df))
        df_scores_off = df_scores_off.append(Eye.GetScores(dfOff,df))

        data_dict = {   'subjectID': subjectID,
                    'dfAll': dfAll,
                    'df_scores_all':df_scores_all,
                    'df_scores_on':df_scores_on,
                    'df_scores_off':df_scores_off           
                        }
    return data_dict

# %% [markdown]
# Object TYPE gaze duration

# %%
df = Eye.PreProcessDf(i['dfAll'])
df_hold = pd.DataFrame()
df_hold['object'] = df['Active Gaze Object Name']
df_hold['deltaTime'] = df['deltaTime']
df_object_duration = df_hold.groupby('object').sum().reset_index()
df_object_type_duration = Eye.GetObjectDurDf2(df_object_duration,df)
dfByType_p = df_object_type_duration.groupby('Type').sum().apply(lambda x:100 * x / float(x.sum())).reset_index()
dfByType_s = df_object_type_duration.groupby('Type').sum().reset_index()
scores = Eye.GetScores(df,df)

# %%
df_object_type_duration
# Out:
#                        Name      Duration         Type
# 0                 Alexander  3.004257e+03        other
# 1          BackWallCollider  3.331158e+02        other
# 2                    Bus002  1.994653e+02        other
# 3                   Cameron  2.261637e+03        other
# 4           CeilingCollider  1.639399e+04        other
# 5              Chair_GRP005  7.421627e+02        other
# 6              Chair_GRP006  8.975700e+00        other
# 7              Chair_GRP007  2.234490e+02        other
# 8              Chair_GRP008  7.372715e+02        other
# 9              Chair_GRP009  8.679663e+02        other
# 10                 Child001  3.756571e+02   distractor
# 11                 Child002  9.035295e+02   distractor
# 12                 Child005  4.866968e+04   distractor
# 13                 Child006  1.842480e+04   distractor
# 14                 Child008  2.933007e+02   distractor
# 15                 Child009  9.687310e+03   distractor
# 16            ClassroomDoor  8.239481e+02        other
# 17            ComputerTable  3.291290e+01        other
# 18    Desk008_Notebook_Open  1.674744e+04        other
# 19  Desk009_Notebook_Closed  1.737792e+03        other
# 20    Desk010_Notebook_Open  2.079925e+03        other
# 21    Desk011_Notebook_Open  1.785132e+02        other
# 22    Desk012_Notebook_Open  2.493510e+01        other
# 23                FrontWall  1.020154e+05        other
# 24           GroundExterior  5.388880e+03        other
# 25                   Houses  4.143258e+03        other
# 26                   Jordan  1.155430e+03        other
# 27                    Kevin  1.854554e+04        other
# 28                 LeftWall  1.834839e+03        other
# 29               Lightposts  6.418902e+02        other
# ..                      ...           ...          ...
# 31                     Null  6.341127e+05        other
# 32               Pedestrian  2.631735e+03   distractor
# 33          ProjectorPodium  7.482587e+03        other
# 34                    Quinn  5.297711e+03        other
# 35        RightWallCollider  1.483033e+03        other
# 36                   Taylor  9.593881e+02        other
# 37            TeachersChair  4.388290e+01        other
# 38             TeachersDesk  7.979000e+00        other
# 39       TeachersDeskPapers  2.094590e+01        other
# 40           UCDavisTeacher  2.918883e+04        other
# 41    WhiteBoardWithDisplay  1.202459e+06  white board
# 42              Whiteboard1  1.062407e+04        other
# 43                   Zayden  3.776843e+02        other
# 44             bookcase0001  4.191060e+01        other
# 45         bulletinboard001  7.978300e+00        other
# 46         bulletinboard002  3.629218e+03        other
# 47         bulletinboard004  1.028832e+03        other
# 48         bulletinboard006  7.978800e+00        other
# 49               cabinet001  4.106262e+02        other
# 50               cabinet002  1.541590e+03        other
# 51                    clock  1.296550e+01        other
# 52       computermoniter002  4.305031e+02        other
# 53       computermoniter003  3.998950e+01        other
# 54       computermoniter004  2.393740e+01        other
# 55           filingCabinet1  3.388570e+01        other
# 56               globe_ball  7.430277e+02        other
# 57                  iPhoneX  1.558898e+03   distractor
# 58                 mouse001  1.196800e+01        other
# 59                  printer  6.443048e+03        other
# 60              wallUnit001  3.913490e+03        other
#
# [61 rows x 3 columns]

# %%
dfByType_p
# Out:
#           Type   Duration
# 0   distractor   3.794968
# 1        other  40.922454
# 2  white board  55.282577

# %%
dfByType_s
# Out:
#           Type      Duration
# 0   distractor  8.254491e+04
# 1        other  8.901103e+05
# 2  white board  1.202459e+06

# %%
dur = dfByType_s.Duration
lab = dfByType_s.Type
plt.pie(dur, labels=lab, autopct='%.1f%%')
plt.show()

# %%
# Total task time (min)
scores.iloc[0,1:2]
# Out:
# Task_duration(min)    36.2519
# Name: 0, dtype: object

# %%
# Percentage of time spent looking at distractors, the whiteboard and other
scores.iloc[0,2:5]
# Out:
# View_duration_distractor(%)    3.79497
# View_duration_other(%)         40.9225
# View_duration_whiteboard(%)    55.2826
# Name: 0, dtype: object

# %%
# Total time (ms) spent looking at distractors, the whiteboard and other
scores.iloc[0,5:9]
# Out:
# View_duration_distractor(ms)                                              82544.9
# View_duration_other(ms)                                                    890110
# View_duration_whiteboard(ms)                                          1.20246e+06
# Object_list                     [WhiteBoardWithDisplay, Null, FrontWall, White...
# Name: 0, dtype: object

# %%
# All objects seen during this period
pd.DataFrame({'objects':scores['Object_list'].tolist()[0]})
# Out:
#                     objects
# 0     WhiteBoardWithDisplay
# 1                      Null
# 2                 FrontWall
# 3               Whiteboard1
# 4                     Quinn
# 5           ProjectorPodium
# 6                  Child006
# 7                 Alexander
# 8              Chair_GRP007
# 9              Chair_GRP009
# 10                 Child009
# 11                   Jordan
# 12  Desk009_Notebook_Closed
# 13                  iPhoneX
# 14           UCDavisTeacher
# 15    Desk010_Notebook_Open
# 16                    Kevin
# 17                  printer
# 18    Desk008_Notebook_Open
# 19           GroundExterior
# 20                 LeftWall
# 21          CeilingCollider
# 22            TeachersChair
# 23                   Taylor
# 24        RightWallCollider
# 25             Chair_GRP008
# 26             Chair_GRP005
# 27    Desk012_Notebook_Open
# 28             bookcase0001
# 29                  Cameron
# ..                      ...
# 31              wallUnit001
# 32                 Child001
# 33                 mouse001
# 34         bulletinboard002
# 35               Lightposts
# 36                   Houses
# 37             TeachersDesk
# 38           filingCabinet1
# 39         BackWallCollider
# 40                 Child005
# 41               globe_ball
# 42    Desk011_Notebook_Open
# 43                 Child002
# 44            ClassroomDoor
# 45       computermoniter002
# 46            ComputerTable
# 47             Chair_GRP006
# 48       computermoniter004
# 49                    clock
# 50         bulletinboard006
# 51                   Zayden
# 52       computermoniter003
# 53                     Noah
# 54       TeachersDeskPapers
# 55         bulletinboard001
# 56                   Bus002
# 57               Pedestrian
# 58                 Child008
# 59               cabinet001
# 60         bulletinboard004
#
# [61 rows x 1 columns]

# %%
# All objects seen during this period
pd.DataFrame({'distractors':scores['Distractor_list'].tolist()[0]})
# Out:
#       distractors
# 0             NaN
# 1        Child009
# 2        Child002
# 3        Child001
# 4         iPhoneX
# 5        iPhoneX2
# 6        Child005
# 7        BusSouth
# 8   NewestTeacher
# 9        Child006
# 10            Car
# 11       BusNorth
# 12       Child008
# 13     Pedestrian

# %%
# distractors this participant looked at
df_object_type_duration[df_object_type_duration.Type == 'distractor']
# Out:
#           Name    Duration        Type
# 10    Child001    375.6571  distractor
# 11    Child002    903.5295  distractor
# 12    Child005  48669.6768  distractor
# 13    Child006  18424.8042  distractor
# 14    Child008    293.3007  distractor
# 15    Child009   9687.3104  distractor
# 32  Pedestrian   2631.7354  distractor
# 57     iPhoneX   1558.8981  distractor

# %%
# we can calculate scores for separate task blocks
i['df_scores_all']
# Out:
#       Task_name  Task_duration(min)  View_duration_distractor(%)  \
# 0  VerbalStroop            4.027628                     3.144518
# 0        AX-CPT            4.004604                     3.144428
# 0          Math            4.058024                     1.474856
# 0  VerbalStroop            4.018056                     5.005545
# 0        AX-CPT            4.006428                     1.345584
# 0          Math            4.057405                     0.189690
# 0  VerbalStroop            4.016615                     4.794814
# 0        AX-CPT            4.005554                     1.655596
# 0          Math            4.057598                     0.864566
#
#    View_duration_other(%)  View_duration_whiteboard(%)  \
# 0               58.646940                    38.208543
# 0               57.408058                    39.447515
# 0               35.335265                    63.189879
# 0               35.676004                    59.318451
# 0               38.279691                    60.374724
# 0               25.063516                    74.746794
# 0               34.150310                    61.054876
# 0               66.137309                    32.207095
# 0               30.607064                    68.528370
#
#    View_duration_distractor(ms)  View_duration_other(ms)  \
# 0                     7598.9684              141724.8361
# 0                     7555.3121              137937.9213
# 0                     3591.0006               86034.8081
# 0                    12067.5357               86008.9029
# 0                     3234.5922               92018.8919
# 0                      461.7891               61015.6986
# 0                    11555.3524               82301.1887
# 0                     3978.9477              158949.9429
# 0                     2104.8356               74514.6961
#
#    View_duration_whiteboard(ms)  \
# 0                    92333.8791
# 0                    94783.0034
# 0                   153855.6234
# 0                   143006.9036
# 0                   145132.1847
# 0                   181966.7981
# 0                   147140.3566
# 0                    77404.3561
# 0                   166836.3431
#
#                                          Object_list  \
# 0  [WhiteBoardWithDisplay, Null, FrontWall, White...
# 0  [Null, WhiteBoardWithDisplay, FrontWall, Ceili...
# 0  [Null, WhiteBoardWithDisplay, Child005, Desk00...
# 0  [FrontWall, WhiteBoardWithDisplay, UCDavisTeac...
# 0  [Null, Child005, CeilingCollider, WhiteBoardWi...
# 0  [WhiteBoardWithDisplay, Whiteboard1, Child005,...
# 0  [WhiteBoardWithDisplay, Null, FrontWall, Kevin...
# 0  [WhiteBoardWithDisplay, FrontWall, Null, Groun...
# 0  [WhiteBoardWithDisplay, Null, UCDavisTeacher, ...
#
#                                      Distractor_list
# 0  [nan, Child009, Child002, Child001, iPhoneX, i...
# 0  [nan, Child006, BusSouth, Child005, Car, BusNo...
# 0  [nan, Child006, iPhoneX2, Child002, Child009, ...
# 0  [nan, Child001, Child009, Child005, Child002, ...
# 0  [nan, Child001, Child006, NewestTeacher, Child...
# 0  [nan, Child002, NewestTeacher, iPhoneX, Child0...
# 0  [nan, NewestTeacher, Child008, Child002, Child...
# 0  [nan, iPhoneX, Pedestrian, Child009, Child006,...
# 0  [nan, Car, Child008, Child006, iPhoneX, Child009]

# %%
# we can calculate scores for separate task blocks filtered by Distraction On
i['df_scores_on']
# Out:
#       Task_name  Task_duration(min)  View_duration_distractor(%)  \
# 0  VerbalStroop            1.602096                     3.196990
# 0        AX-CPT            1.578244                     3.885230
# 0          Math            1.671088                     3.581501
# 0  VerbalStroop            1.704065                     7.439873
# 0        AX-CPT            1.833420                     2.697423
# 0          Math            1.297342                     0.562499
# 0  VerbalStroop            1.999179                     5.864504
# 0        AX-CPT            1.756636                     2.552431
# 0          Math            1.430223                     2.009993
#
#    View_duration_other(%)  View_duration_whiteboard(%)  \
# 0               57.883568                    38.919442
# 0               58.660452                    37.454317
# 0               31.183922                    65.234577
# 0               43.092566                    49.467561
# 0               36.148840                    61.153737
# 0               30.912394                    68.525108
# 0               36.796592                    57.338904
# 0               64.781332                    32.666237
# 0               33.421445                    64.568561
#
#    View_duration_distractor(ms)  View_duration_other(ms)  \
# 0                     3073.1312               55641.0175
# 0                     3679.1047               55548.2996
# 0                     3591.0006               31266.6381
# 0                     7606.8184               44059.5315
# 0                     2967.3059               39765.6044
# 0                      437.8519               24062.3677
# 0                     7034.5157               44137.7829
# 0                     2690.2156               68278.3381
# 0                     1724.8429               28680.0689
#
#    View_duration_whiteboard(ms)  \
# 0                    37411.6079
# 0                    35467.2277
# 0                    65407.6139
# 0                    50577.5765
# 0                    67272.2921
# 0                    53340.2995
# 0                    68778.4382
# 0                    34429.6164
# 0                    55408.4589
#
#                                          Object_list  \
# 0  [WhiteBoardWithDisplay, Null, FrontWall, White...
# 0  [Null, WhiteBoardWithDisplay, FrontWall, Ceili...
# 0  [Null, WhiteBoardWithDisplay, Child005, Desk00...
# 0  [FrontWall, WhiteBoardWithDisplay, UCDavisTeac...
# 0  [Null, Child005, CeilingCollider, WhiteBoardWi...
# 0  [WhiteBoardWithDisplay, Whiteboard1, Child005,...
# 0  [WhiteBoardWithDisplay, Null, FrontWall, Kevin...
# 0  [WhiteBoardWithDisplay, FrontWall, Null, Groun...
# 0  [WhiteBoardWithDisplay, Null, UCDavisTeacher, ...
#
#                                      Distractor_list
# 0  [nan, Child009, Child002, Child001, iPhoneX, i...
# 0  [nan, Child006, BusSouth, Child005, Car, BusNo...
# 0  [nan, Child006, iPhoneX2, Child002, Child009, ...
# 0  [nan, Child001, Child009, Child005, Child002, ...
# 0  [nan, Child001, Child006, NewestTeacher, Child...
# 0  [nan, Child002, NewestTeacher, iPhoneX, Child0...
# 0  [nan, NewestTeacher, Child008, Child002, Child...
# 0  [nan, iPhoneX, Pedestrian, Child009, Child006,...
# 0  [nan, Car, Child008, Child006, iPhoneX, Child009]

# %%
# we can calculate scores for separate task blocks filtered by Distraction Off
i['df_scores_off']
# Out:
#       Task_name  Task_duration(min)  View_duration_distractor(%)  \
# 0  VerbalStroop            2.425532                     3.109859
# 0        AX-CPT            2.426360                     2.662567
# 0          Math            2.386936                     0.000000
# 0  VerbalStroop            2.313990                     3.212861
# 0        AX-CPT            2.173008                     0.205005
# 0          Math            2.760063                     0.014455
# 0  VerbalStroop            2.017436                     3.734804
# 0        AX-CPT            2.248918                     0.955076
# 0          Math            2.627375                     0.241047
#
#    View_duration_other(%)  View_duration_whiteboard(%)  \
# 0               59.151157                    37.738984
# 0               56.593429                    40.744005
# 0               38.241608                    61.758392
# 0               30.214310                    66.572829
# 0               40.077543                    59.717452
# 0               22.314306                    77.671240
# 0               31.527977                    64.737219
# 0               67.196467                    31.848457
# 0               29.075044                    70.683909
#
#    View_duration_distractor(ms)  View_duration_other(ms)  \
# 0                     4525.8372               86083.8186
# 0                     3876.2074               82389.6217
# 0                        0.0000               54768.1700
# 0                     4460.7173               41949.3714
# 0                      267.2863               52253.2875
# 0                       23.9372               36953.3309
# 0                     4520.8367               38163.4058
# 0                     1288.7321               90671.6048
# 0                      379.9927               45834.6272
#
#    View_duration_whiteboard(ms)  \
# 0                    54922.2712
# 0                    59315.7757
# 0                    88448.0095
# 0                    92429.3271
# 0                    77859.8926
# 0                   128626.4986
# 0                    78361.9184
# 0                    42974.7397
# 0                   111427.8842
#
#                                          Object_list  \
# 0  [WhiteBoardWithDisplay, Null, FrontWall, White...
# 0  [Null, WhiteBoardWithDisplay, FrontWall, Ceili...
# 0  [Null, WhiteBoardWithDisplay, Child005, Desk00...
# 0  [FrontWall, WhiteBoardWithDisplay, UCDavisTeac...
# 0  [Null, Child005, CeilingCollider, WhiteBoardWi...
# 0  [WhiteBoardWithDisplay, Whiteboard1, Child005,...
# 0  [WhiteBoardWithDisplay, Null, FrontWall, Kevin...
# 0  [WhiteBoardWithDisplay, FrontWall, Null, Groun...
# 0  [WhiteBoardWithDisplay, Null, UCDavisTeacher, ...
#
#                                      Distractor_list
# 0  [nan, Child009, Child002, Child001, iPhoneX, i...
# 0  [nan, Child006, BusSouth, Child005, Car, BusNo...
# 0  [nan, Child006, iPhoneX2, Child002, Child009, ...
# 0  [nan, Child001, Child009, Child005, Child002, ...
# 0  [nan, Child001, Child006, NewestTeacher, Child...
# 0  [nan, Child002, NewestTeacher, iPhoneX, Child0...
# 0  [nan, NewestTeacher, Child008, Child002, Child...
# 0  [nan, iPhoneX, Pedestrian, Child009, Child006,...
# 0  [nan, Car, Child008, Child006, iPhoneX, Child009]

# %% [markdown]
# ## Unnecessary, preliminary stats
#
# For each of the three datasets, lets compute a paired t-test statistic, **Distractor On** (% of distractor view duration) vs **Distractor Off** (% of distractor view duration)

# %%
for i in resultsList:
    print(i['subjectID'])
    print(stats.ttest_rel(i['df_scores_on']['View_duration_distractor(%)'],i['df_scores_off']['View_duration_distractor(%)']))
# Out:
# 19202
# Ttest_relResult(statistic=1.7448832185705643, pvalue=0.12451898959684793)
# 19205
# Ttest_relResult(statistic=3.2002393793198145, pvalue=0.015060802543077916)
# 19201
# Ttest_relResult(statistic=4.402630661792442, pvalue=0.0022787288021962277)
